# %%
import requests

# %%
requests.get("https://euw1.api.riotgames.com/lol/match/v4/matches/5275615366?api_key=RGAPI-72b7b68b-1309-44ec-a78b-89b17742448a")
# Out:
# <Response [200]>

# %%
response = requests.get("https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/KC%20Isnow?api_key=RGAPI-72b7b68b-1309-44ec-a78b-89b17742448a")
response.json()
# Out:
# {'id': 'Z2bfMio01qPjPdWaMX_2Xr89PT2IDmi4iuHFbS2eazTGQl5Tdbe4aFLWcA',
#  'accountId': '1Q69y9VDie8nz__-dBgm_IlQ0McrVp3rrFI8U1_Lrdbmzi0rHNOBTmxK',
#  'puuid': 'ROukO09gYPGXJpWcKB8MTx9si7e7tzTJDLsr9cdg-u94-n48LXX19FjyQ92ZsLPkYjFYivqxbh6McQ',
#  'name': 'KC Isnow',
#  'profileIconId': 1213,
#  'revisionDate': 1621632586000,
#  'summonerLevel': 33}

# %%
response = requests.get ("https://euw1.api.riotgames.com/lol/status/v4/platform-data?api_key=RGAPI-72b7b68b-1309-44ec-a78b-89b17742448a")
response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8389639c5a4d> in <module>
# ----> 1 response = requests.get ("https://euw1.api.riotgames.com/lol/status/v4/platform-data?api_key=RGAPI-72b7b68b-1309-44ec-a78b-89b17742448a")
#       2 response.json()
#
# NameError: name 'requests' is not defined

# %%
response = requests.get("https://euw1.api.riotgames.com/lol/match/v4/matches/5275615366?api_key=RGAPI-72b7b68b-1309-44ec-a78b-89b17742448a")
response.json()
# Out:
# {'gameId': 5275615366,
#  'platformId': 'EUW1',
#  'gameCreation': 1621363980976,
#  'gameDuration': 1704,
#  'queueId': 420,
#  'mapId': 11,
#  'seasonId': 13,
#  'gameVersion': '11.10.374.9538',
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'teams': [{'teamId': 100,
#    'win': 'Fail',
#    'firstBlood': True,
#    'firstTower': True,
#    'firstInhibitor': False,
#    'firstBaron': False,
#    'firstDragon': False,
#    'firstRiftHerald': True,
#    'towerKills': 2,
#    'inhibitorKills': 0,
#    'baronKills': 0,
#    'dragonKills': 0,
#    'vilemawKills': 0,
#    'riftHeraldKills': 2,
#    'dominionVictoryScore': 0,
#    'bans': [{'championId': 777, 'pickTurn': 1},
#     {'championId': 53, 'pickTurn': 2},
#     {'championId': 11, 'pickTurn': 3},
#     {'championId': 10, 'pickTurn': 4},
#     {'championId': 99, 'pickTurn': 5}]},
#   {'teamId': 200,
#    'win': 'Win',
#    'firstBlood': False,
#    'firstTower': False,
#    'firstInhibitor': True,
# ...

# %%
response.json()['gameId']
# Out:
# 5275615366

# %%
response.json()['participants'][7]
# Out:
# {'participantId': 8,
#  'teamId': 200,
#  'championId': 412,
#  'spell1Id': 4,
#  'spell2Id': 3,
#  'stats': {'participantId': 8,
#   'win': True,
#   'item0': 3860,
#   'item1': 2424,
#   'item2': 3190,
#   'item3': 3117,
#   'item4': 3050,
#   'item5': 0,
#   'item6': 3364,
#   'kills': 0,
#   'deaths': 5,
#   'assists': 18,
#   'largestKillingSpree': 0,
#   'largestMultiKill': 0,
#   'killingSprees': 0,
#   'longestTimeSpentLiving': 491,
#   'doubleKills': 0,
#   'tripleKills': 0,
#   'quadraKills': 0,
#   'pentaKills': 0,
#   'unrealKills': 0,
#   'totalDamageDealt': 24613,
#   'magicDamageDealt': 12903,
#   'physicalDamageDealt': 6923,
#   'trueDamageDealt': 4787,
#   'largestCriticalStrike': 0,
#   'totalDamageDealtToChampions': 6536,
#   'magicDamageDealtToChampions': 5700,
#   'physicalDamageDealtToChampions': 835,
#   'trueDamageDealtToChampions': 0,
#   'totalHeal': 3124,
#   'totalUnitsHealed': 5,
#   'damageSelfMitigated': 13000,
#   'damageDealtToObjectives': 3145,
# ...

# %%
response = requests.get("https://euw1.api.riotgames.com/lol/platform/v3/champion-rotations?api_key=RGAPI-72b7b68b-1309-44ec-a78b-89b17742448a")
response.json()
# Out:
# {'freeChampionIds': [11,
#   15,
#   20,
#   31,
#   36,
#   55,
#   102,
#   131,
#   133,
#   136,
#   164,
#   201,
#   350,
#   498,
#   516],
#  'freeChampionIdsForNewPlayers': [18, 81, 92, 141, 37, 238, 19, 45, 25, 64],
#  'maxNewPlayerLevel': 10}

# %%
# Out:
# 11
